# %%
import matplotlib.pyplot as plt 
import numpy as np
# %matplotlib inline

def f(x):
    ret = 0
    for i in range(100):
        cur = 1
        for i in range(2*i+2):
            cur *= x / max(1, i)
        ret += cur * (-1)**i
    return ret

x = np.linspace(1, 100, 100)
plt.plot(x, f(x))

plt.show()
